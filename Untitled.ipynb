# %%
import pandas as pd
from IPython.display import display
df = pd.read_csv("src/Database/Dataset.csv")

# %%
print(df.columns.tolist())
df.info()
#df.head()
display(df)
# Out:
# ['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date', 'revenue', 'runtime', 'adult', 'backdrop_path', 'budget', 'homepage', 'imdb_id', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'tagline', 'genres', 'production_companies', 'production_countries', 'spoken_languages', 'keywords']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1261153 entries, 0 to 1261152
# Data columns (total 24 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1261153 non-null  int64
#  1   title                 1261140 non-null  object
#  2   vote_average          1261153 non-null  float64
#  3   vote_count            1261153 non-null  int64
#  4   status                1261153 non-null  object
#  5   release_date          1019142 non-null  object
#  6   revenue               1261153 non-null  int64
#  7   runtime               1261153 non-null  int64
# ...

# %%
df.shape
# Out:
# (1261153, 10)

# %%
# 1. Schwellenwert (hier 50 %)
threshold = len(df) * 0.5

# 2. Spalten ermitteln, bei denen null_counts > threshold
cols_to_drop = null_counts[null_counts > threshold].index.tolist()

# 3. Spalten löschen
df = df.drop(columns=cols_to_drop)

# Kontrolle
df.info()

# %%
#Oder wir nehmen nur die Zelle die auch gebraucht werden, statt das wir die Schwellenwert überprüfen

keep = [
    'popularity',    # wie oft der Film aufgerufen wurde
    'vote_count',
    'budget',        # oder besser: budget_log = np.log1p(budget)
    'revenue',       # bzw. revenue_log
    'runtime',
    'release_date',  # besser: release_year & release_month
    'status',
    'original_language',
    'adult',
    'vote_average'   # deine Ziel­variable
]

# Filtere df auf genau diese Spalten:
df = df[keep].copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1261153 entries, 0 to 1261152
# Data columns (total 10 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   popularity         1261153 non-null  float64
#  1   vote_count         1261153 non-null  int64
#  2   budget             1261153 non-null  int64
#  3   revenue            1261153 non-null  int64
#  4   runtime            1261153 non-null  int64
#  5   release_date       1019142 non-null  object
#  6   status             1261153 non-null  object
#  7   original_language  1261153 non-null  object
#  8   adult              1261153 non-null  bool
#  9   vote_average       1261153 non-null  float64
# dtypes: bool(1), float64(2), int64(4), object(3)
# memory usage: 87.8+ MB
